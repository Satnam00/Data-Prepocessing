# %%
import numpy as np
import pandas as pd

# %% [markdown]
# determinant of the correlation matrix will
# - range from 0 (Perfect Collinearity) to 1 (No Collinearity)

# %%
# Create a sample random dataframe
np.random.seed(321)

x1 = np.random.rand(100)
x2 = np.random.rand(100)
x3 = np.random.rand(100)

df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
# Out:
#           x1        x2        x3
# 0   0.885948  0.272524  0.796244
# 1   0.077912  0.673294  0.851090
# 2   0.979646  0.297522  0.397434
# 3   0.247671  0.945230  0.945796
# 4   0.752885  0.698001  0.568400
# 5   0.526676  0.736862  0.629374
# 6   0.907554  0.907857  0.429053
# 7   0.884070  0.099350  0.287916
# 8   0.089269  0.463650  0.382786
# 9   0.517345  0.011577  0.711586
# 10  0.343621  0.282330  0.972644
# 11  0.212294  0.783381  0.334747
# 12  0.360673  0.254344  0.717528
# 13  0.270775  0.306071  0.840742
# 14  0.761625  0.028471  0.884264
# 15  0.478042  0.549365  0.551080
# 16  0.098995  0.271332  0.899618
# 17  0.275395  0.182271  0.777860
# 18  0.794427  0.865699  0.687676
# 19  0.513970  0.157286  0.345148
# 20  0.453295  0.255209  0.863180
# 21  0.255151  0.654640  0.845978
# 22  0.113977  0.022609  0.082610
# 23  0.824313  0.961913  0.876251
# 24  0.317753  0.897617  0.045265
# 25  0.152307  0.120550  0.425737
# 26  0.214980  0.722090  0.613798
# 27  0.912110  0.958745  0.610372
# 28  0.043115  0.494278  0.519219
# 29  0.375952  0.938786  0.538095
# ..       ...       ...       ...
# 70  0.711262  0.623800  0.036952
# 71  0.515640  0.294328  0.286677
# 72  0.328492  0.742265  0.281075
# 73  0.618746  0.316045  0.738340
# 74  0.828440  0.040458  0.291783
# 75  0.518931  0.670785  0.992070
# 76  0.651465  0.128300  0.353261
# 77  0.846990  0.039629  0.625716
# 78  0.477965  0.797066  0.907397
# 79  0.720382  0.023662  0.552208
# 80  0.705722  0.350117  0.380473
# 81  0.774465  0.945745  0.811939
# 82  0.157823  0.182427  0.426341
# 83  0.100435  0.792960  0.334793
# 84  0.639838  0.066210  0.697573
# 85  0.122242  0.774758  0.123189
# 86  0.543643  0.824564  0.395147
# 87  0.422783  0.872008  0.159775
# 88  0.749381  0.996188  0.310797
# 89  0.013976  0.671798  0.038841
# 90  0.849257  0.204903  0.919921
# 91  0.779674  0.087394  0.282045
# 92  0.238075  0.718709  0.697090
# 93  0.870240  0.224255  0.305865
# 94  0.443698  0.576668  0.636235
# 95  0.185789  0.789603  0.771333
# 96  0.927266  0.352212  0.435965
# 97  0.146010  0.601235  0.262798
# 98  0.563783  0.984145  0.866654
# 99  0.938598  0.182860  0.963173
#
# [100 rows x 3 columns]

# %%
# Now create a dataframe with multicollinearity
multicollinear_df = df.copy()

multicollinear_df['x3'] = multicollinear_df['x1'] + multicollinear_df['x2']

# %%
# Compute both correlation matrices
corr = np.corrcoef(df, rowvar=0)

multicollinear_corr = np.corrcoef(multicollinear_df, rowvar=0)

# %%
corr, multicollinear_corr
# Out:
# (array([[ 1.        , -0.08946765,  0.04154055],
#         [-0.08946765,  1.        , -0.04556837],
#         [ 0.04154055, -0.04556837,  1.        ]]),
#  array([[ 1.        , -0.08946765,  0.66595731],
#         [-0.08946765,  1.        ,  0.6834166 ],
#         [ 0.66595731,  0.6834166 ,  1.        ]]))

# %%
df.corr()
# Out:
#           x1        x2        x3
# x1  1.000000 -0.089468  0.041541
# x2 -0.089468  1.000000 -0.045568
# x3  0.041541 -0.045568  1.000000

# %%
multicollinear_df.corr()
# Out:
#           x1        x2        x3
# x1  1.000000 -0.089468  0.665957
# x2 -0.089468  1.000000  0.683417
# x3  0.665957  0.683417  1.000000

# %% [markdown]
# 0 - Perfect Collinearity
#
# 1 - No Collinearity

# %%
# Compare the determinants
print (np.linalg.det(corr))                 # 0.988532159861
print (np.linalg.det(multicollinear_corr))  # 2.97779797328e-16
# Out:
# 0.9885321598605282
# 2.977797973278992e-16
